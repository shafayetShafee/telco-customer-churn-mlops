# %%
# %reload_ext kedro.ipython
# %load_ext kedro.ipython
# Out:
# [04/07/26 02:27:52] INFO     Registered line magic '%reload_kedro'                                   ]8;id=818870;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=217931;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#64\64]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=267087;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=439015;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#66\66]8;;\
# ...

# %%
X_train = catalog.load("X_train")
X_calib = catalog.load("X_calib")
X_test = catalog.load("X_test")
# Out:
# [04/07/26 01:16:48] INFO     Loading data from X_train (ParquetDataset)...                     ]8;id=459378;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=760880;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
#                     INFO     Loading data from X_calib (ParquetDataset)...                     ]8;id=656801;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=113880;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
# ...

# %%
X_train.shape, X_test.shape, X_calib.shape
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ((4923, 23), (1055, 23), (1055, 23))

# %%
X_train.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       gender  senior_citizen  partner  dependents  tenure  phone_service  \
# 2424       1               0        0           0      30              1
# 4163       0               0        0           0      12              1
# 1786       0               0        1           0      44              1
# 3194       1               0        0           0       1              1
# 5532       0               0        1           0      67              1
#
#       online_security  online_backup  device_protection  tech_support  ...  \
# 2424                1              0                  1             0  ...
# 4163                0              0                  0             0  ...
# 1786                1              1                  1             0  ...
# 3194                0              0                  0             0  ...
# ...

# %%
ops = catalog.load('optuna_search')
# Out:
# [04/07/26 02:28:28] INFO     Loading data from optuna_search (PickleDataset)...                ]8;id=927740;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=198960;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
#                     WARNING  /Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3 ]8;id=220332;file:///Users/pathaoltd/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=522584;file:///Users/pathaoltd/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/warnings.py#110\110]8;;\
#                              .11/site-packages/tqdm/auto.py:21: TqdmWarning: IProgress not found.
#                              Please update jupyter and ipywidgets. See
# ...

# %%
ops.study_.direction
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [<StudyDirection.MAXIMIZE: 2>]

# %%
ops.study_.best_value
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0.6741173080869893

# %%
ops.study_.sampler
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...

# %%
ops.study_.pruner
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...
