# %%
# %load_ext kedro.ipython
# Out:
# [04/06/26 16:01:03] INFO     Using                                                                  ]8;id=451126;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=952132;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/framework/project/__init__.py#269\269]8;;\
#                              '/Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python
#                              3.11/site-packages/kedro/framework/project/rich_logging.yml' as
#                              logging configuration.
# ...

# %%
import pandas as pd

# %%
import sys
sys.path.append("src")

# %%
from telco_customer_churn_mlops.pipelines.ml_app.nodes_ml.hyperparameter_tuning import tune_xgb_pr_auc

# %%
X_train = catalog.load("X_train")
# Out:
# [04/06/26 16:08:04] INFO     Loading data from X_train (ParquetDataset)...                     ]8;id=380623;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=625511;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\

# %%
X_train.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       gender  senior_citizen  partner  dependents  tenure  phone_service  \
# 3835       0               0        1           1      24              1
# 5394       0               0        1           0      48              1
# 661        0               0        0           0      10              1
# 3092       0               0        0           0       1              0
# 2107       1               0        1           0      33              1
#
#       online_security  online_backup  device_protection  tech_support  ...  \
# 3835                0              0                  0             0  ...
# 5394                0              1                  0             1  ...
# 661                 0              0                  0             0  ...
# 3092                0              0                  0             0  ...
# ...

# %%
y_train = catalog.load("y_train")
# Out:
# [04/06/26 16:08:18] INFO     Loading data from y_train (ParquetDataset)...                     ]8;id=596429;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=368212;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\

# %%
y_train.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       churn
# 3835      0
# 5394      0
# 661       0
# 3092      1
# 2107      0

# %%
X_test = catalog.load("X_test")
y_test = catalog.load("y_test")
# Out:
# [04/06/26 16:09:12] INFO     Loading data from X_test (ParquetDataset)...                      ]8;id=918412;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=870535;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
#                     INFO     Loading data from y_test (ParquetDataset)...                      ]8;id=848174;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=598529;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\

# %%
res = tune_xgb_pr_auc(
    X_train, y_train, X_test, y_test
)
# Out:
# [I 2026-04-06 16:10:18,976] A new study created in memory with name: no-name-43389466-3cf8-4d89-ae6e-ce59b30cb886
# [W 2026-04-06 16:10:19,162] Trial 0 failed with parameters: {'n_estimators': 542, 'learning_rate': 0.05218325869158803, 'max_depth': 6, 'subsample': 0.6565693590469857, 'colsample_bytree': 0.5199841113905724, 'min_child_weight': 9, 'gamma': 0.15679707448519764, 'reg_alpha': 1.3112014210191063, 'reg_lambda': 1.164602145162713} because of the following error: XGBoostError("Invalid Parameter format for scale_pos_weight expect float but value='churn    2.768562\ndtype: float64'").
# Traceback (most recent call last):
#   File "/Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
# ...

# %%
dir(y_train)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'T',
#     '_AXIS_LEN',
#     '_AXIS_ORDERS',
#     '_AXIS_TO_AXIS_NUMBER',
#     '_HANDLED_TYPES',
#     '__abs__',
#     '__add__',
#     '__and__',
#     '__annotations__',
#     '__array__',
#     '__array_priority__',
#     '__array_ufunc__',
#     '__arrow_c_stream__',
#     '__bool__',
#     '__class__',
#     '__contains__',
#     '__copy__',
#     '__dataframe__',
#     '__dataframe_consortium_standard__',
#     '__deepcopy__',
#     '__delattr__',
#     '__delitem__',
#     '__dict__',
#     '__dir__',
#     '__divmod__',
#     '__doc__',
#     '__eq__',
#     '__finalize__',
#     '__floordiv__',
#     '__format__',
#     '__ge__',
#     '__getattr__',
#     '__getattribute__',
#     '__getitem__',
#     '__getstate__',
#     '__gt__',
#     '__hash__',
#     '__iadd__',
#     '__iand__',
#     '__ifloordiv__',
# ...

# %%
y_train['churn'].values
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# array([0, 0, 0, ..., 0, 0, 0], shape=(5634,))
