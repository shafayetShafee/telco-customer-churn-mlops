# %%
# %reload_ext kedro.ipython
# Out:
# [04/06/26 17:57:56] INFO     Registered line magic '%reload_kedro'                                   ]8;id=72174;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=302974;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#64\64]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=870745;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=86980;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/ipython/__init__.py#66\66]8;;\
# ...

# %%
X_train = catalog.load("X_train")
y_train = catalog.load("y_train")
X_test = catalog.load("X_test")
y_test = catalog.load("y_test")
# Out:
# [04/06/26 16:40:23] INFO     Loading data from X_train (ParquetDataset)...                     ]8;id=984391;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=977194;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
#                     INFO     Loading data from y_train (PickleDataset)...                      ]8;id=389327;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=98071;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
# ...

# %%
catalog.load('optuna_best_params')
# Out:
# [04/06/26 16:44:22] INFO     Loading data from optuna_best_params (PickleDataset)...           ]8;id=659773;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=318308;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {
#     'n_estimators': 366,
#     'learning_rate': 0.0404632306949045,
#     'max_depth': 8,
#     'subsample': 0.7673003690705703,
#     'colsample_bytree': 0.6995620372961227,
#     'min_child_weight': 2,
#     'gamma': 2.6836088538986083,
#     'reg_alpha': 3.07459899522485,
#     'reg_lambda': 0.9297997613254857,
#     'random_state': 1070,
#     'n_jobs': -1,
#     'scale_pos_weight': np.float64(2.768561872909699),
#     'eval_metric': 'logloss'
# ...

# %%
st = catalog.load('optuna_study')
# Out:
# [04/06/26 16:44:56] INFO     Loading data from optuna_study (PickleDataset)...                 ]8;id=421738;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=855168;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\

# %%
st.best_values
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0.6701688884820797

# %%
bt = catalog.load("best_threshold")
# Out:
# [04/06/26 16:57:32] INFO     Loading data from best_threshold (PickleDataset)...               ]8;id=686555;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=882623;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\

# %%
bt
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0.56

# %%
bt_df = catalog.load('tuning_threshold_df')
# Out:
# [04/06/26 16:57:56] INFO     Loading data from tuning_threshold_df (ParquetDataset)...         ]8;id=752291;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=297930;file:///Users/pathaoltd/Projects/telco-customer-churn-mlops/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
bt_df.query('recall>=0.78')
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#     threshold  precision    recall        f1       tpr       fpr  accuracy
# 0        0.00   0.265353  1.000000  0.419414  1.000000  1.000000  0.265353
# 1        0.01   0.265353  1.000000  0.419414  1.000000  1.000000  0.265353
# 2        0.02   0.265872  1.000000  0.420062  1.000000  0.997342  0.267306
# 3        0.03   0.279178  1.000000  0.436496  1.000000  0.932592  0.314874
# 4        0.04   0.297690  1.000000  0.458800  1.000000  0.852138  0.373979
# 5        0.05   0.311042  0.998662  0.474345  0.998662  0.798985  0.412673
# 6        0.06   0.324418  0.997993  0.489662  0.997993  0.750664  0.447994
# 7        0.07   0.334682  0.995987  0.501009  0.995987  0.715149  0.473553
# 8        0.08   0.344524  0.995318  0.511868  0.995318  0.683982  0.496273
# 9        0.09   0.351039  0.994649  0.518932  0.994649  0.664170  0.510650
# ...

# %%
(
    bt_df
    .set_index('threshold')
    .plot()
)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Axes: xlabel='threshold'>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %%
from telco_customer_churn_mlops.pipelines.ml_app.nodes_ml.threshold_tuning import plot_threshold_metrics

# %%
plot_threshold_metrics(
    bt_df
)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1000x600 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1000x600 with 1 Axes>
